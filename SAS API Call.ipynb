# %%
import requests
import json

KEYS_TO_EXTRACT = ['creationTimeStamp', 'id', 'name', 'publishName', 'publishType']

def read_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

def extract_items_as_json(data, keys_to_extract):
    if 'items' in data and isinstance(data['items'], list):
        extracted_items = [
            {
                key: item[key] for key in keys_to_extract if key in item
            }
            for item in data['items']
        ]
        return extracted_items  # Return the extracted items as a Python dictionary
    else:
        return []  # Return an empty list if 'items' is not in data or not a list

class SASDeployClient:
    def __init__(self):
        self.base_url = 'https://sasserver.demo.sas.com'
        self.headers = read_json('headers.json')

    def send_request(self, type, url, payload=None):
        if payload is None:
            return requests.request(
                type, 
                url, 
                headers=self.headers, 
                verify='../trustedcerts.pem')
        else:
            return requests.request(
                type, 
                url, 
                headers=self.headers, 
                data=payload, 
                verify='../trustedcerts.pem')
    
    def get_joblist(self, payload):
        request_url = self.base_url + "/jobExecution/jobs"
        response = self.send_request("GET", request_url, payload)
        
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Failed to retrieve job list: {response.status_code}")
            return None

    def get_published_flows(self):
        request_url = self.base_url + "/modelPublish/models"
        response = self.send_request("GET", request_url)

        data = response.json()

        result = extract_items_as_json(data, KEYS_TO_EXTRACT)
        
        if response.status_code == 200:
            return result
        else:
            print(f"Failed to retrieve job list: {response.status_code}")
            return None

    def import_json_obj(self):
        request_url = self.base_url + "/transfer/importJobs"
        response = self.send_request("POST", request_url)

        return response

# %%
app = SASDeployClient()

data = app.get_published_flows()
type(data)
# Out:
# str

# %%
json.loads(data)
# Out:
# [{'creationTimeStamp': '2024-02-23T22:41:10.962773Z',
#   'id': 'c1a711ad-f667-4249-8ad9-9f50f5aa12d7',
#   'name': 'lbzx3kdnf4fhfzjdgdeqqxjq7fm',
#   'publishName': 'lbzx3kdnf4fhfzjdgdeqqxjq7fm',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-02-23T22:41:43.315328Z',
#   'id': 'd4a46783-3901-4c58-a3cb-cb874f95618c',
#   'name': 'lmedt22s6fzaztjs5unrc2ryfzq',
#   'publishName': 'lmedt22s6fzaztjs5unrc2ryfzq',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-04T08:46:21.013332Z',
#   'id': '70b7a117-5c84-43fb-9b7b-822f04a0c2a1',
#   'name': 'ml1_income_lgbm',
#   'publishName': 'ml1_income_lgbm',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-04T08:46:47.484047Z',
#   'id': '3a54ee03-dfcf-4731-9d88-b6ae840faa1e',
#   'name': 'ml2_cluster_kmeans',
#   'publishName': 'ml2_cluster_kmeans',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-04T08:47:15.423911Z',
#   'id': '546d33e9-18a3-400a-a026-3266b9ed9164',
#   'name': 'RB_Macro_PD_Calibrated__Pipeline_1_',
#   'publishName': 'RB_Macro_PD_Calibrated__Pipeline_1_',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-04T08:47:31.014004Z',
#   'id': '3e25394f-aac8-43be-95ab-b8d36ed3aaad',
#   'name': 'RB_Micro_PD_Calibrated__Pipeline_1_',
#   'publishName': 'RB_Micro_PD_Calibrated__Pipeline_1_',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-05T01:28:05.640728Z',
#   'id': '68174989-dc90-4218-b115-4eb652e20b2d',
#   'name': 'EB_S1_ASSIGN_CUSTOMER_FLOW_DF1_0',
#   'publishName': 'EB_S1_ASSIGN_CUSTOMER_FLOW_DF1_0',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-05T22:34:20.124111Z',
#   'id': 'a1b69df3-66fd-41b9-8428-dd4b16ae5bfd',
#   'name': 'sid_global_variable_container',
#   'publishName': 'sid_global_variable_container',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-05T22:34:55.619369Z',
#   'id': '39b20ee3-7af9-43b1-81f8-8ffc6dafcbb6',
#   'name': 'sid_global_variable_container',
#   'publishName': 'sid_global_variable_container',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-05T22:53:25.085646Z',
#   'id': 'ad40c849-67d5-483a-9962-2370f4cd9473',
#   'name': 'sid_global_variable_container',
#   'publishName': 'sid_global_variable_container',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-06T02:30:43.530789Z',
#   'id': 'aa5fc0fa-ec80-4c01-83ff-18aea8e17df7',
#   'name': 'lsruolffvhnho7gxne4ixrszylm',
#   'publishName': 'lsruolffvhnho7gxne4ixrszylm',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-06T07:24:40.22633Z',
#   'id': '5f5ea1d0-fa13-411f-bbaa-c794797d90f7',
#   'name': 'RB_Scenario_Main_Flow_DF1_CAS',
#   'publishName': 'RB_Scenario_Main_Flow_DF1_CAS',
#   'publishType': 'casModel'},
#  {'creationTimeStamp': '2024-06-06T07:30:57.903004Z',
#   'id': 'f2b23db0-361a-4fe2-a786-df214181a908',
#   'name': 'RB_Scenario_Main_Flow_DF1_1',
#   'publishName': 'RB_Scenario_Main_Flow_DF1_1',
#   'publishType': 'casModel'},
#  {'creationTimeStamp': '2024-06-06T08:07:15.170105Z',
#   'id': '86a688e1-97d9-4134-aeb0-330b31974f43',
#   'name': 'RB_Macro_PD_Calibrated__Pipeline_1_',
#   'publishName': 'RB_Macro_PD_Calibrated__Pipeline_1_',
#   'publishType': 'casModel'},
#  {'creationTimeStamp': '2024-06-06T08:09:41.961136Z',
#   'id': '6091cf47-fdff-41ab-a888-cbe55a62a150',
#   'name': 'RB_Micro_PD_Calibrated__Pipeline_1_',
#   'publishName': 'RB_Micro_PD_Calibrated__Pipeline_1_',
#   'publishType': 'casModel'},
#  {'creationTimeStamp': '2024-06-06T08:13:01.044283Z',
#   'id': 'd35b041b-9e66-42da-aaf3-37715f5b19be',
#   'name': 'ml1_income_lgbm',
#   'publishName': 'ml1_income_lgbm',
#   'publishType': 'casModel'},
#  {'creationTimeStamp': '2024-06-06T08:14:50.057037Z',
#   'id': 'd27cb723-2f02-4c91-9468-eb1e34f17b68',
#   'name': 'ml2_cluster_kmeans',
#   'publishName': 'ml2_cluster_kmeans',
#   'publishType': 'casModel'},
#  {'creationTimeStamp': '2024-06-06T22:23:03.515206Z',
#   'id': '33bdb739-e316-483d-8000-1a62a345b066',
#   'name': 'sid_global_variable_container',
#   'publishName': 'sid_global_variable_container',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-06T22:36:28.912468Z',
#   'id': 'b694ff73-0c94-4692-b4cd-db97d348aac5',
#   'name': 'EB_S1_OPRISK_DF2_0',
#   'publishName': 'EB_S1_OPRISK_DF2_0',
#   'publishType': 'mas'},
#  {'creationTimeStamp': '2024-06-07T04:41:01.01805Z',
#   'id': 'c7760a0b-18c1-45cb-bd9a-2c5204526126',
#   'name': 'ml1_income_lgbm',
#   'publishName': 'ml1_income_lgbm',
#   'publishType': 'casModel'}]

# %%
app = SASDeployClient()

payload = json.dumps({
  "jobDefinition": {
    "type": "validateDecision"
  },
  "arguments": {
    "decisionId": "63f49f1e-8ce0-4f35-9a44-0f941c4a7a38",
    "decisionRevisionId": "003e50fa-473a-472a-b101-1ef7f4133178",
    "reset": "false"
  }
})

app.get_joblist(payload)

# %%
https://sasserver.demo.sas.com/decisions/flows/
